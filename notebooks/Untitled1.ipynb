# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/2025-02-metropolitan-street.csv")

# %%
df.shape
# Out:
# (83660, 12)

# %%
print(df.columns.tolist())
# Out:
# ['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude', 'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type', 'Last outcome category', 'Context']

# %%
print(df.isnull().sum())
# Out:
# Crime ID                 15246
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                    0
# Latitude                     0
# Location                     0
# LSOA code                    0
# LSOA name                    0
# Crime type                   0
# Last outcome category    15246
# Context                  83660
# dtype: int64
